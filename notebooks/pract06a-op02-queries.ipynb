-- %% [markdown]
-- INNER JOIN

-- %%
USE practica6a_join;
SELECT * 
FROM usuario u 
INNER JOIN orden o
ON u.UserID = o.UserID;
-- Out:
-- Commands completed successfully
-- (2 row(s) affected)
-- Total execution time: 00:00:01.015
-- <table><tr><th>UserID</th><th>UserName</th><th>OrderID</th><th>UserID</th></tr><tr><td>123</td><td>Bob</td><td>222</td><td>123</td></tr><tr><td>123</td><td>Bob</td><td>333</td><td>123</td></tr></table>

-- %% [markdown]
-- ![inner-join.PNG](attachment:inner-join.PNG)

-- %% [markdown]
-- LEFT JOIN

-- %%
SELECT * 
FROM usuario u 
LEFT JOIN orden o 
ON u.UserID = o.UserId;
-- Out:
-- (4 row(s) affected)
-- Total execution time: 00:00:01.004
-- <table><tr><th>UserID</th><th>UserName</th><th>OrderID</th><th>UserID</th></tr><tr><td>123</td><td>Bob</td><td>333</td><td>123</td></tr><tr><td>123</td><td>Bob</td><td>222</td><td>123</td></tr><tr><td>124</td><td>Alice</td><td>NULL</td><td>NULL</td></tr><tr><td>125</td><td>Carrie</td><td>NULL</td><td>NULL</td></tr></table>

-- %% [markdown]
-- ![left-join.PNG](attachment:left-join.PNG)

-- %% [markdown]
-- RIGHT JOIN

-- %%
SELECT * 
FROM usuario u 
RIGHT JOIN orden o 
ON u.UserID = o.UserID;
-- Out:
-- (4 row(s) affected)
-- Total execution time: 00:00:01.011
-- <table><tr><th>UserID</th><th>UserName</th><th>OrderID</th><th>UserID</th></tr><tr><td>NULL</td><td>NULL</td><td>111</td><td>126</td></tr><tr><td>123</td><td>Bob</td><td>222</td><td>123</td></tr><tr><td>123</td><td>Bob</td><td>333</td><td>123</td></tr><tr><td>NULL</td><td>NULL</td><td>666</td><td>126</td></tr></table>

-- %% [markdown]
-- ![right-join.PNG](attachment:right-join.PNG)

-- %% [markdown]
-- FULL OUTER JOIN

-- %%
SELECT * 
FROM usuario u 
FULL OUTER JOIN orden o 
ON u.UserID = o.UserID;
-- Out:
-- Total execution time: 00:00:00
-- : 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'FULL OUTER JOIN orden o
-- ON u.UserID = o.UserID' at line 3

-- %% [markdown]
-- <span style="color: rgb(13, 13, 13); font-family: Söhne, ui-sans-serif, system-ui, -apple-system, &quot;Segoe UI&quot;, Roboto, Ubuntu, Cantarell, &quot;Noto Sans&quot;, sans-serif, &quot;Helvetica Neue&quot;, Arial, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Noto Color Emoji&quot;; font-size: 16px; white-space-collapse: preserve; background-color: rgb(255, 255, 255);">MySQL no admite la sintaxis de FULL OUTER JOIN directamente.</span>
--
-- <span style="color: rgb(13, 13, 13); font-family: Söhne, ui-sans-serif, system-ui, -apple-system, &quot;Segoe UI&quot;, Roboto, Ubuntu, Cantarell, &quot;Noto Sans&quot;, sans-serif, &quot;Helvetica Neue&quot;, Arial, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;, &quot;Noto Color Emoji&quot;; font-size: 16px; white-space-collapse: preserve; background-color: rgb(255, 255, 255);">Para superar este problema, podemos simular un FULL OUTER JOIN utilizando UNION de LEFT JOIN y RIGHT JOIN.</span>

-- %%
SELECT *
FROM usuario u
LEFT JOIN orden o ON u.UserID = o.UserID
UNION
SELECT *
FROM usuario u
RIGHT JOIN orden o ON u.UserID = o.UserID;
-- Out:
-- (6 row(s) affected)
-- Total execution time: 00:00:01.011
-- <table><tr><th>UserID</th><th>UserName</th><th>OrderID</th><th>UserID</th></tr><tr><td>123</td><td>Bob</td><td>333</td><td>123</td></tr><tr><td>123</td><td>Bob</td><td>222</td><td>123</td></tr><tr><td>124</td><td>Alice</td><td>NULL</td><td>NULL</td></tr><tr><td>125</td><td>Carrie</td><td>NULL</td><td>NULL</td></tr><tr><td>NULL</td><td>NULL</td><td>111</td><td>126</td></tr><tr><td>NULL</td><td>NULL</td><td>666</td><td>126</td></tr></table>

-- %% [markdown]
-- ![full-outer-join.PNG](attachment:full-outer-join.PNG)
